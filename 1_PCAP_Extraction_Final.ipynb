# %%
from os import listdir
from os.path import isfile, join
import os
import json
import zipfile
import re
import pkgutil
import os
import encodings
import subprocess

class AutoVivification(dict):
    """Implementation of perl's autovivification feature."""
    def __getitem__(self, item):
        try:
            return dict.__getitem__(self, item)
        except KeyError:
            value = self[item] = type(self)()
            return value

        
# Encodings function
def all_encodings():
    modnames = set(
        [modname for importer, modname, ispkg in pkgutil.walk_packages(
            path=[os.path.dirname(encodings.__file__)], prefix='')])
    aliases = set(encodings.aliases.aliases.values())
    return modnames.union(aliases)

# file_type function requirements

magic_dict = {
    "\x1f\x8b\x08": "gz",
    "\x42\x5a\x68": "bz2",
    "\x50\x4b\x03\x04": "zip"
    }

max_len = max(len(x) for x in magic_dict)

def file_type(filename_in):
    encodings = all_encodings()
    for enc in encodings:
        try:
            with open(filename_in, encoding=enc) as f_in:
                file_start = f_in.read(max_len)
        except:
            pass
    for magic, filetype in magic_dict.items():
        if file_start.startswith(magic):
            return filetype
    return "no match"

def extractfiles(out_dir,zipname,password):
    system = subprocess.Popen(["7z", "x", "-o{}".format(out_dir), zipname, "-p{}".format(password)])
    return(system.communicate())

#os.walk(directory)
pcaps_dir='/home/cc/Contagio'
directories = [x[0] for x in os.walk(pcaps_dir)]
directories = [ x for x in directories if "MACOSX" not in x ]

#Variables
cnt_pcap=0
cnt_p=0
cnt_wrong_pwd=0
my_dict = AutoVivification()

for i_dir in range(1,len(directories)):
    print(directories[i_dir] + "\n")
    mypath = directories[i_dir]
    
    #onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f)) and f.endswith('.zip') or f.endswith('.ZIP')]
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f)) and file_type(mypath + "/" + f)=="zip"]
    non_compressed_files = [f for f in listdir(mypath) if isfile(join(mypath, f)) and file_type(mypath + "/" + f)=="no match"]
    #onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
    for file_x in onlyfiles:
        fullpath = mypath + "/" + file_x
        ###print(fullpath)
        ###print(file_type(fullpath))
        ###print("\n")
    if not os.path.exists(directories[i_dir] + "/unziped"):
        os.makedirs(directories[i_dir] + "/unziped")

    destination_dir = directories[i_dir] + "/unziped"
    for file in onlyfiles:
        ###print("\n"+ directories[i_dir] + "/" + file)
        path_to_zip_file = directories[i_dir] + "/" + file
        try:
            cnt_pcap=cnt_pcap+1
            zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
            zip_ref.extractall(destination_dir)
            zip_ref.close()
            ###print("Extraction Succesful")
            my_dict[directories[i_dir]]['Successful'][file]=None
            
        except:
            cnt_pcap=cnt_pcap-1
            ###print("Password Required")
            cnt_p=cnt_p+1
            try:
                zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
                zip_ref.extractall(destination_dir,None,pwd=b'infected666p')
                zip_ref.close()
                cnt_p=cnt_p-1
                cnt_pcap=cnt_pcap+1
                ###print("Extraction Succesful")
                my_dict[directories[i_dir]]['Successful'][file]=None
            except:
                try:
                    zip_ref = zipfile.ZipFile(path_to_zip_file, 'r')
                    zip_ref.extractall(destination_dir,None,pwd=b'infected666t')
                    zip_ref.close()
                    cnt_p=cnt_p-1
                    cnt_pcap=cnt_pcap+1
                    ###print("Extraction Succesful")
                    my_dict[directories[i_dir]]['Successful'][file]=None
                except:
                    try:
                        system = subprocess.Popen(["7z", "x", "-o{}".format(destination_dir), path_to_zip_file, "-p{}".format("infected666p")])
                        cnt_p=cnt_p-1
                        cnt_pcap=cnt_pcap+1
                        ###print("Extraction Succesful")
                        my_dict[directories[i_dir]]['Successful'][file]=None
                    except:
                        ###print("***** Invalid Password *****")
                        ###print(system.communicate())
                        try:
                            system = subprocess.Popen(["7z", "x", "-o{}".format(destination_dir), path_to_zip_file, "-p{}".format("infected666t")])
                            cnt_p=cnt_p-1
                            cnt_pcap=cnt_pcap+1
                            ###print("Extraction Succesful")
                            my_dict[directories[i_dir]]['Successful'][file]=None
                        except:
                            cnt_wrong_pwd=cnt_wrong_pwd+1
                            print("***** Invalid Password *****")
                            #print(system.communicate())
                            my_dict[directories[i_dir]]['Pending'][file]=None
            
    onlyfiles=[]
    

print("\nFinal Results")
print("Successful Extractions: %s" %cnt_pcap)
print("Unsuccessful Extractions: %s" %cnt_p)
print("Invalid Passwords: %s" %cnt_wrong_pwd)
print("\nDictionary")
print(json.dumps(my_dict, sort_keys=True, indent=4))
print("\nCompressed files")
print(onlyfiles)
print("\nNon_compressed_files")
print(non_compressed_files)
# Out:
# /home/cc/Contagio/Exploit_Kits_and_Malware
#
# /home/cc/Contagio/Exploits_and_Scans
#
# /home/cc/Contagio/APT
#
# /home/cc/Contagio/GENERAL_DEFCON_17
#
# /home/cc/Contagio/General
#
# /home/cc/Contagio/CRIME
#
#
# Final Results
# Successful Extractions: 1152
# Unsuccessful Extractions: 0
# Invalid Passwords: 0
#
# Dictionary
# {
#     "/home/cc/Contagio/APT": {
#         "Successful": {
#             "8202_tbd_ 6D2C12085F0018DAEB9C1A53E53FD4D1-pcap.zip": null,
#             "BIN_8202_6d2c12085f0018daeb9c1a53e53fd4d1-pcap.zip": null,
#             "BIN_9002_D4ED654BCDA42576FDDFE03361608CAA_2013-01-30-pcap.zip": null,
#             "BIN_BIN_RssFeeder_68EE5FDA371E4AC48DAD7FCB2C94BAC7-2012-06-pcap.zip": null,
#             "BIN_DNSWatch_protux_4F8A44EF66384CCFAB737C8D7ADB4BB8_2012-11-pcap.zip": null,
#             "BIN_Darkcomet_DC98ABBA995771480AECF4769A88756E-pcap.zip": null,
#             "BIN_Enfal_Lurid_0fb1b0833f723682346041d72ed112f9_2013-01-pcap.zip": null,
#             "BIN_Gh0st-gif_f4d4076dff760eb92e4ae559c2dc4525-pcap.zip": null,
#             "BIN_Gh0st_variant-v2010_B1D09374006E20FA795B2E70BF566C6D_2012-08-pcap.zip": null,
#             "BIN_Hupigon_8F90057AB244BD8B612CD09F566EAC0C-pcap.zip": null,
#             "BIN_IXESHE_0F88D9B0D237B5FCDC0F985A548254F2-2013-05-pcap.zip": null,
#             "BIN_LURK_AF4E8D4BE4481D0420CCF1C00792F484_20120-10-pcap.zip": null,
#             "BIN_Lagulon_e8b1f23616f9d8493e8a1bf0ca0f512a-pcap.zip": null,
#             "BIN_LetsGo_yahoosb_b21ba443726385c11802a8ad731771c0_2011-07-19-pcap.zip": null,
#             "BIN_Likseput_E019E37F19040059AB5662563F06B609_2012-10-pcap.zip": null,
#             "BIN_Mediana_0AE47E3261EA0A2DBCE471B28DFFE007_2012-10-pcap.zip": null,
#             "BIN_Mswab_Yayih_FD1BE09E499E8E380424B3835FC973A8_2012-03-pcap.zip": null,
#             "BIN_Nettravler-pcap.zip": null,
#             "BIN_OnionDuke_28F96A57FA5FF663926E9BAD51A1D0CB-pcap.zip": null,
#             "BIN_Pingbed_74fc916a0187f3d491ef9fb0b540f228-pcap.zip": null,
#             "BIN_PlugX_2ff2d518313475a612f095dd863c8aea-pcap.zip": null,
#             "BIN_Sanny-Daws_338D0B855421867732E05399A2D56670_2012-10-pcap.zip": null,
#             "BIN_Scieron-21BF6BD26E3D505B4A6C2B9C2B1DC2F1-pcap.zip": null,
#             "BIN_Taidoor_40D79D1120638688AC7D9497CC819462_2012-10-pcap.zip": null,
#             "BIN_Taidoor_46ef9b0f1419e26f2f37d9d3495c499f-pcap.zip": null,
#             "BIN_Taleret.E_5328cfcb46ef18ecf7ba0d21a7adc02c-pcap.zip": null,
#             "BIN_Tapaoux_60AF79FB0BD2C9F33375035609C931CB_winver_2011-08-23-pcap.zip": null,
#             "BIN_TrojanCookies_840BD11343D140916F45223BA05ABACB_2012_01-pcap.zip": null,
#             "BIN_TrojanPage_86893886C7CBC7310F7675F4EFDE0A29-pcap.zip": null,
#             "BIN_Vidgrab_660709324acb88ef11f71782af28a1f0-pcap.zip": null,
#             "BIN_Vidgrab_6fd868e68037040c94215566852230ab-pcap.zip": null,
#             "BIN_XTremeRAT_DAEBFDED736903D234214ED4821EAF99_2013-04-13-pcap.zip": null,
#             "BIN_XtremeRat_7a76b5c158de1203cd614e9546e5c738-pcap.zip": null,
#             "PDF_CVE-2011-2462_Pdf_2011-12-pcap.zip": null,
#             "RTF_Mongall_Dropper_Cve-2012-0158_C6F01A6AD70DA7A554D48BDBF7C7E065_2013-01-pcap.zip": null,
#             "Xinmic_8761F29AF1AE2D6FACD0AE5F487484A5-pcap.zip": null
#         }
#     },
#     "/home/cc/Contagio/CRIME": {
#         "Successful": {
#             "BIN_Alienspy_RAT_and Pony_pcap.zip": null,
#             "BIN_AlinaSpark_BE6371B8C90D8EECB749311373CEC0ED-pcap.zip": null,
#             "BIN_Alinav5.3_4C754150639AA3A86CA4D6B6342820BE-pcap.zip": null,
#             "BIN_Alurewo_alureon_2502edca284bd8bf782a65123a22f9a6-pcap.zip": null,
#             "BIN_Andromeda_85F908A5BD0ADA2D72D138E038AECC7D_2013-04-pcap.zip": null,
#             "BIN_ArdamaxKeylogger_E33AF9E602CBB7AC3634C2608150DD18-pcap.zip": null,
#             "BIN_BitcoinMiner_F865C199024105A2FFDF5FA98F391D74-pcap.zip": null,
#             "BIN_Bitcoinminer_12E717293715939C5196E604591A97DF-2013-05-12-pcap.zip": null,
#             "BIN_Cerber_A16D0430D5C47D1007F88919979A7654_pcap.pcap_06_05_2016_17-10-01.pcap_06_05_2016_23-42-01.pcap.zip": null,
#             "BIN_ChePro_2A5E5D3C536DA346849750A4B8C8613A-pcap.zip": null,
#             "BIN_Cidox_Nuclear-EK_malware-traff-analysis-blog_2014-08-06-pcap.zip": null,
#             "BIN_CitadelPacked_2012-05-pcap.zip": null,
#             "BIN_CitadelUnpacked_2012-05-pcap.zip": null,
#             "BIN_Citadel_3D6046E1218FB525805E5D8FDC605361-2013-04-pcap.zip": null,
#             "BIN_Cutwail-Pushdo_582DE032477E099EB1024D84C73E98C1-pcap.zip": null,
#             "BIN_Cutwail_284Fb18Fab33C93Bc69Ce392D08Fd250_2012-10-pcap.zip": null,
#             "BIN_DMALocker_6ACB3D1B3F199452118EA80DCFF57728.pcap.zip": null,
#             "BIN_DNSChanger_2011-12-pcap.zip": null,
#             "BIN_Darkmegi_2012-04_pcap.zip": null,
#             "BIN_DarknessDDoS_v8g_F03Bc8Dcc090607F38Ffb3A36Ccacf48_2011-01-pcap.zip": null,
#             "BIN_Drowor_worm_0f015bb8e2f93fd7076f8d178df2450d_2013-04-pcap.zip": null,
#             "BIN_GameThief_ECBA0FEB36F9EF975EE96D1694C8164C_2013-03-pcap.zip": null,
#             "BIN_Googledocs_macadocs_2012-12-pcap.zip": null,
#             "BIN_Gypthoy_3EE49121300384FF3C82EB9A1F06F288-pcap.zip": null,
#             "BIN_HorstProxy_EFE5529D697174914938F4ABF115F762-2013-05-13-pcap.zip": null,
#             "BIN_IRCbot_c6716a417f82ccedf0f860b735ac0187_2013-04-pcap.zip": null,
#             "BIN_Imaut_823e9bab188ad8cb30c14adc7e67066d-pcap.zip": null,
#             "BIN_Kelihos_C94DC5C9BB7B99658C275B7337C64B33-pcap.zip": null,
#             "BIN_Kelihos_aka_Nap_0feaaa4adc31728e54b006ab9a7e6afa-pcap.zip": null,
#             "BIN_Kuluoz-Asprox_9F842AD20C50AD1AAB41F20B321BF84B-pcap.zip": null,
#             "BIN_Lader-dlGameoverZeus_12cfe1caa12991102d79a366d3aa79e9-pcap.zip": null,
#             "BIN_LoadMoney_MailRu_dl_4e801b46068b31b82dac65885a58ed9e_2013-04-pcap.zip": null,
#             "BIN_MatsnuMBRwiping_1B2D2A4B97C7C2727D571BBF9376F54F-pcap.zip": null,
#             "BIN_Netwire_79e6ea386833b2443fe093cf0c1e8c66-2014-11-30-pcap.zip": null,
#             "BIN_Nitedrem_508af8c499102ad2ebc1a83fdbcefecb-pcap.zip": null,
#             "BIN_Nocpos_3def6f8d1b709e61b83e9a697d64e129-pcap.zip": null,
#             "BIN_PUP_Selfinstall_9f26de41c7520929ea4f4f7e61abe1a6-pcap.zip": null,
#             "BIN_PassAlert_B4A1368515C6C39ACEF63A4BC368EDB2-2013-05-13.zip": null,
#             "BIN_Pony_B5E7CD42B45F8670ADAF96BBCA5AE2D0-pcap.zip": null,
#             "BIN_Ponyloader-Zeus_B10393BE747143F3B4622E9E5277FFCE-pcap.zip": null,
#             "BIN_PowerLoader_4497A231DA9BD0EEA327DDEC4B31DA12_2013-05-pcap.zip": null,
#             "BIN_Prosti-Screenblaze_00001ffe4e2c3218db5eecfd16b97a9-pcapf.zip": null,
#             "BIN_Ramnitpcap_2012-01-pcap.zip": null,
#             "BIN_Reedum_0CA4F93A848CF01348336A8C6FF22DAF_well-samp.zip": null,
#             "BIN_Reedum_0ca4f93a848cf01348336a8c6ff22daf_2013-03-pcap.zip": null,
#             "BIN_Sality_03fa78bd6c71d76a50e63ab0b9a4505f-pcap.zip": null,
#             "BIN_Scudy_5c085d004270abbc6a21151e60a984d1-pcap.zip": null,
#             "BIN_SpyEye_2010-02-pcap.zip": null,
#             "BIN_Stabuniq_F31B797831B36A4877AA0FD173A7A4A2_2012-12-pcap.zip": null,
#             "BIN_Tijcont_845B0945D5FE0E0AAA16234DC21484E0-pcap.zip": null,
#             "BIN_Tinba_2012-06-pcap.zip": null,
#             "BIN_TinyZBot_96e372dea573714d34e394550059b1d7-pcap.zip": null,
#             "BIN_Toopu-pcap.zip": null,
#             "BIN_Twerket_a27721f3b9566601030daab58c092c14-pcap.zip": null,
#             "BIN_UStealD_2b796f11f15e8c73f8f69180cf74b39d-pcap.zip": null,
#             "BIN_Vobfus_634AA845F5B0B519B6D8A8670B994906_2012-12-pcap.zip": null,
#             "BIN_Wauchos_Zbot_0d8d7a8074ee36a626d086f02490aaab-pcap.zip": null,
#             "BIN_Win.Trojan.Waski_document_234787_pdf.exe_ee299b606ea2165a88a06c3347c0319b.zip": null,
#             "BIN_Wordpress_Mutopy_Symmi_20A6EBF61243B760DD65F897236B6AD3-2pcap.zip": null,
#             "BIN_Xpaj_2012-05-pcap.zip": null,
#             "BIN_ZeroAccess_3169969E91F5FE5446909BBAB6E14D5D_2012-10-pcap.zip": null,
#             "BIN_ZeroAccess_Sirefef_29A35124ABEAD63CD8DB2BBB469CBC7A_2013-05-pcapc.zip": null,
#             "BIN_ZeroAccess_Sirefef_C2A9CCC8C6A6DF1CA1725F955F991940_2013-08-pcap.zip": null,
#             "BIN_ZeusGameover_2012-02-pcap.zip": null,
#             "BIN_Zeus_b1551c676a54e9127cd0e7ea283b92cc-2012-04-pcap.zip": null,
#             "BIN_Zeus_outbound_1-25050_2014-10-08-phishing-malware-analysis-from-malwr.com-pcap.zip": null,
#             "BIN_cryptolocker_9CBB128E8211A7CD00729C159815CB1C-pcap.zip": null,
#             "BIN_dirtjumper_2011-10-pcap.zip": null,
#             "BIN_fd0ff4992247bbcc2bde6379e10c1499_Hyteod-pcap.zip": null,
#             "BIN_locky_B4D0B65C6243B4213D1488E37F816159.pcap_05_29_2016_22-30-01.pcap.zip": null,
#             "BIN_purplehaze-pihar-A1B3E59AE17BA6F940AFAF86485E5907-2012-02.zip": null,
#             "BIN_sality_CEAF4D9E1F408299144E75D7F29C1810-pcap.zip": null,
#             "BIN_tbot-pcap.zip": null,
#             "BIN_torpigminiloader-pcap.zip": null,
#             "EK_BIN_Blackhole_leadingto_Medfos_0512E73000BCCCE5AFD2E9329972208A_2013-04-pcap.zip": null,
#             "EK_Blackhole_55A60EBB5EC6079C52CEDB6CB1DC48AD-pcap.zip": null,
#             "EK_Blackhole_Java_CVE-2012-4681_2012-08-pcap.zip": null,
#             "EK_Blackholev1-pcap.zip": null,
#             "EK_Blackholev2_2012-09-pcap.zip": null,
#             "EK_CDN-gate_malw-traf-analysis-blog_2014-09-04-Sweet-Orange-EK-pcap.zip": null,
#             "EK_Malware_traffic_analysis_blog_2014-05-19-FlashPack-EK-traffic-pcap.zip": null,
#             "EK_Smokekt150(Malwaredontneedcoffee)_2012-09-pcap.zip": null,
#             "EK_Styx+BIN_Simda_Proxyer_Malware_traffic_analysis_blog_2014-03-15-Styx-EK-traffic_pcap.zip": null,
#             "EK_popads_109.236.80.170_2013-08-13-pcap.zip": null,
#             "OSX_DocksterTrojan-pcap.zip": null,
#             "Sality-pcap.zip": null,
#             "Sality_03fa78bd6c71d76a50e63ab0b9a4505f-samp.zip": null,
#             "tbotpcaps.zip": null
#         }
#     },
#     "/home/cc/Contagio/Exploit_Kits_and_Malware": {
#         "Successful": {
#             "EK_MALWARE_2013-06-18-Neutrino-EK-traffic_mailware-traffic-analysis.net.pcap.ZIP": null,
#             "EK_MALWARE_2013
mailware-traffic-analysis.net.pcap.ZIP": null,
#             "EK_MALWARE_2014-10-09-Magnitude-EK-traffic_mailware-traffic-analysis.net.pcap.ZIP": null,
#             "GENERAL_80211-WEPauth_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_80211-WEPauthfail_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_80211-WPAauth_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_80211-WPAauthfail_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_80211beacon_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_80211traffic_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_FailedWEPAuth_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_HackChallenge_Cmas2010_CounterHack.pcap.ZIP": null,
#             "GENERAL_HackChallenge_Cmas2011_CounterHack.pcap.ZIP": null,
#             "GENERAL_Java-1.6.0_30.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.6.0_31.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.6.0_32.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.6.0_33.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.6.0_37.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.6.0_38.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.7.0_05.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.7.0_09.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.7.0_10.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Java-1.7.0_4.UA.session_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_OpenVPN-update-check_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_PDF-in-XPD-Safe-Example_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_Pandora-radio-xml_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_SIP_SIPp_g711a_Saghul.pcap.ZIP": null,
#             "GENERAL_SuccessfulWEPAuth_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL__SIP_SIPp_g722_Saghul.pcap.ZIP": null,
#             "GENERAL__SIP_SIPp_h264.pcap.ZIP": null,
#             "GENERAL_activeosfingerprinting_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_allworkandnoplayencoded_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_allworkandnoplayplain_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_allworkpost_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_arp_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_arp_gratuitous_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_arp_resolution_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_arppoison_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_barryscomputer_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_bethscomputer_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_cisco_anyconnect_cve2011-2039_reverse_meterprter_test1_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_covertinfo_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_destunreachable_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_dhcp_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_dhcp_inlease_renewal_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_dhcp_nolease_renewal_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_dns_PracticalPacketAnalysis.cap.ZIP": null,
#             "GENERAL_dns_axfr_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_dns_query_response_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_dns_recursivequery_client_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_dns_recursivequery_server_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_dosattack_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_double-vision_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_email-troubles_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_evidence-defcon2010_NetworkForensics.pcap.ZIP": null,
#             "GENERAL_evilprogram_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_ftp-crack_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_ftp-uploadfailed_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_ftp_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_ftpbounceattack_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_ftpclientdenied_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_ftpserverdenied_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_gnutella_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_hackersview_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_hauntedbrowser_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_http-client-refuse_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_http-fault-post_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_http_PracticalPacketAnalysis.cap.ZIP": null,
#             "GENERAL_http_espn_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_http_google_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_icmp-tracert-slow_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_icmp_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_icmp_echo_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_ip_frag_source_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_ipfragments_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_jackcr-challenge.pcap.ZIP": null,
#             "GENERAL_malware_ratinfected_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_metasploit_aurora_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_msnms_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_oisfsearchnums_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_osfingerprinting_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_php-cgi-badness-CVE-2012-1823_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_portscan_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_printerproblem_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_puzzle1.pcap_NetworkForensics.tgz.ZIP": null,
#             "GENERAL_rpcoversmbtraffic_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_slowdownload_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_synscan_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_tcp-con-lost_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_tcp_dupack_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_tcp_handshake_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_tcp_retransmissions_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_tcp_teardown_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_tcp_zerowindowdead_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_tcp_zerowindowrecovery_chrissanders.org.pcap.ZIP": null,
#             "GENERAL_telnet-raw_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_telnet_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_tor2webdnslookup_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_torrential-slowness_PracticalPacketAnalysis.pcap.ZIP": null,
#             "GENERAL_x-flash-header-10-3-183-20_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_x-flash-header-11-3-300-257_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_x-flash-version-11-2-202-235_EmergingThreats.pcap.ZIP": null,
#             "GENERAL_x-flash-version-header-v-11-2-202-233_EmergingThreats.pcap.ZIP": null
#         }
#     }
# }
#
# Compressed files
# []
#
# Non_compressed_files
# ['.DS_Store']
