# %%
import pyshark
import os
from os.path import isfile, join
from os import listdir
from pprint import pprint
import re

def print_highest_layer(pkt):
    print (pkt.highest_layer)

def get_capture_count(pkt):
    count = []
    def counter(*args):
        count.append(args[0])
    pkt.apply_on_packets(counter, timeout=100000)
    return len(count)

def extract(dict_in, dict_out):
    for key, value in dict_in.iteritems():
        if isinstance(value, dict): # If value itself is dictionary
            extract(value, dict_out)
        elif isinstance(value, unicode):
            # Write to dict_out
            dict_out[key] = value
    return dict_out

#uncpx_pcaps_dir = []
'''
for key, value in my_dict.items():
    uncpx_pcaps_dir.append(key+"/unziped")
'''
pcaps_dir='/home/cc/Contagio'
directories = [x[0] for x in os.walk(pcaps_dir)]
#directories = [ x for x in directories if "MACOSX" not in x and "unziped" in x]
#for dir in directories:
#    uncpx_pcaps_dir.append(dir+"/unziped")
    
print(directories)
uncpx_pcaps_dir = directories
eth_list = []
ip_list = []
udp_list = []
dns_list = []
tcp_list = []
icmp_list = []
http_list = []
data_list = []
media_list = []
png_list = []
json_list = []
image_list = []
ssl_list = []
tls_list = []
failed_pcaps=[]
pkt_layers_full=[]

ip_output_dict = {}

for pcap_dir in uncpx_pcaps_dir[0:1]: #uncpx_pcaps_dir[0:1]
    pcap_dir = "/home/cc/Contagio/Exploit_Kits_and_Malware"
    print("\n")
    print(pcap_dir)
    pcap_dir_files = [f for f in listdir(pcap_dir) if isfile(join(pcap_dir, f))]
    #print(pcap_dir_files)
    print("\n")
    ####pcap_dir_files = ["EK_MALWARE_2015-01-08-pcap-files-associated-with-malware-from-82.244.160.22_mailware-traffic-analysis.net.zip"]
    ###pcap_dir_files = ["EK_MALWARE_2014-03-09-callback-traffic-from-physical-host_mailware-traffic-analysis.net.pcap"]
    #pcap_dir_files = ["BIN_Gh0st-gif_f4d4076dff760eb92e4ae559c2dc4525.pcap"]
    #pcap_dir_files = ["BIN_TrojanCookies_840BD11343D140916F45223BA05ABACB_2012_01.pcap"]
    pcap_dir_files = ["EK_MALWARE_2014-04-29-fake-flash-updater-02_mailware-traffic-analysis.net.pcap"]
    for i_cap in pcap_dir_files:
        cap = pyshark.FileCapture(pcap_dir+'/'+i_cap, keep_packets=False)
        print("Current PCAP:")
        print(pcap_dir+'/'+i_cap)
        try:
            print("Capture Count:")
            print(get_capture_count(cap))
            print("\n")
            #print("\n PCAP Highest Layer:")
            #print_highest_layer(cap[0])

            pkt_num = 0
            for i_pkt in cap:
                #print("\n *** PKT: %s ***" %pkt_num)
                i_pkt_layers = []
                i_pkt_layers = re.findall(r'<(\w+)', str(i_pkt.layers))
                #print(i_pkt_layers)
                for i_layer in i_pkt_layers:
                    pkt_layers_full.append(i_layer)
                pkt_num = pkt_num+1
                if "SSL" in i_pkt_layers:
                    print("\n *** PKT: %s ***" %pkt_num)
                    print(i_pkt_layers)
                    #pprint(type(i_pkt.eth))
                    #pprint(type(i_pkt.eth._all_fields))
                    #print(i_pkt.eth._all_fields)
                    #print("Pretty Print")
                    #pprint(i_pkt.eth._all_fields)
                    try:
                        print("--- ETH LAYER ---")
                        pprint(i_pkt.eth._all_fields)
                        #pprint(i_pkt.eth._all_fields.keys())
                        for key in i_pkt.eth._all_fields.keys():
                            eth_list.append(key)
                    except:
                        pass
                    try:
                        print("--- IP LAYER ---")
                        #print('\nAllFields\n')
                        #print(type(pprint(i_pkt.ip._all_fields)))
                        pprint(i_pkt.ip._all_fields)
                        #pprint(i_pkt.ip._all_fields.keys())
                        for key in i_pkt.ip._all_fields.keys():
                            ip_list.append(key)
                        #print('\nExtracted Dict\n')
                        #extract(i_pkt.ip._all_fields,ip_output_dict)
                        #pprint(ip_output_dict)
                    except:
                        pass
                    try:
                        print("--- UDP LAYER ---")
                        pprint(i_pkt.udp._all_fields)
                        #pprint(i_pkt.udp._all_fields.keys())
                        for key in i_pkt.udp._all_fields.keys():
                            udp_list.append(key)
                    except:
                        pass
                    try:
                        print("--- DNS LAYER ---")
                        pprint(i_pkt.dns._all_fields)
                        #pprint(i_pkt.dns._all_fields.keys())
                        for key in i_pkt.dns._all_fields.keys():
                            dns_list.append(key)
                    except:
                        pass
                    try:
                        print("--- TCP LAYER ---")
                        pprint(i_pkt.tcp._all_fields)
                        #pprint(i_pkt.tcp._all_fields.keys())
                        for key in i_pkt.tcp._all_fields.keys():
                            tcp_list.append(key)
                    except:
                        pass
                    try:
                        print("--- HTTP LAYER ---")
                        pprint(i_pkt.http._all_fields)
                        for key in i_pkt.http._all_fields.keys():
                            http_list.append(key)
                    except:
                        pass
                    try:
                        print("--- SSL LAYER ---")
                        pprint(i_pkt.ssl._all_fields)
                        for key in i_pkt.ssl._all_fields.keys():
                            ssl_list.append(key)
                    except:
                        pass
                    try:
                        print("--- TLS LAYER ---")
                        pprint(i_pkt.tls._all_fields)
                        for key in i_pkt.tls._all_fields.keys():
                            tls_list.append(key)
                    except:
                        pass
        except:
            failed_pcaps.append(pcap_dir+'/'+i_cap)
            print("\n")
            pass

        
# Get unique values
eth_set = list(set(eth_list))
ip_set = list(set(ip_list))
udp_set = list(set(udp_list))
dns_set = list(set(dns_list))
tcp_set = list(set(tcp_list))
http_set = list(set(http_list))
ssl_set = list(set(ssl_list))
tls_set = list(set(tls_list))

pkt_layers_full_set = list(set(pkt_layers_full))
print("Layers")
print(pkt_layers_full_set)
print("\nFailed PCAPS")
print(failed_pcaps)

print("ETH Set")
print(eth_set)
print("IP Set")
print(ip_set)
print("UDP Set")
print(udp_set)
print("DNS Set")
print(dns_set)
print("TCP Set")
print(tcp_set)
print("HTTP Set")
print(http_set)
print("SSL Set")
print(ssl_set)
print("TLS Set")
print(tls_set)
# Out:
# ['/home/cc/Contagio', '/home/cc/Contagio/Exploit_Kits_and_Malware', '/home/cc/Contagio/Exploit_Kits_and_Malware/EK_MALWARE_2014-08-13-sandbox-analysis-pcap-files_mailware-traffic-analysis.net', '/home/cc/Contagio/Exploit_Kits_and_Malware/EK_MALWARE_2015-01-08-pcap-files-associated-with-malware-from-82.244.160.22_mailware-traffic-analysis.net', '/home/cc/Contagio/Exploits_and_Scans', '/home/cc/Contagio/APT', '/home/cc/Contagio/GENERAL_DEFCON_17', '/home/cc/Contagio/General', '/home/cc/Contagio/CRIME', '/home/cc/Contagio/CRIME/tbotpcaps']
#
#
# /home/cc/Contagio/Exploit_Kits_and_Malware
#
#
# Current PCAP:
# /home/cc/Contagio/Exploit_Kits_and_Malware/EK_MALWARE_2014-04-29-fake-flash-updater-02_mailware-traffic-analysis.net.pcap
# Capture Count:
# 2884
#
#
#
#  *** PKT: 2693 ***
# ['ETH', 'IP', 'TCP', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:50:56:f9:05:c4',
#  'eth.addr_resolved': '00:50:56:f9:05:c4',
#  'eth.dst': '00:50:56:f9:05:c4',
#  'eth.dst_resolved': '00:50:56:f9:05:c4',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:0c:29:8a:cb:e9',
#  'eth.src_resolved': '00:0c:29:8a:cb:e9',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: Unknown',
#  'ip.addr': '172.16.223.132',
#  'ip.checksum': '0x00000000',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '134.170.109.176',
#  'ip.dst_host': '134.170.109.176',
#  'ip.flags': '0x00000002',
#  'ip.flags.df': '1',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.dst_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '172.16.223.132',
#  'ip.id': '0x00000432',
#  'ip.len': '112',
#  'ip.proto': '6',
#  'ip.src': '172.16.223.132',
#  'ip.src_host': '172.16.223.132',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '1',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '72',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '72',
#  'tcp.checksum': '0x00008052',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '443',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '72',
#  'tcp.nxtseq': '73',
#  'tcp.port': '49212',
#  'tcp.seq': '1',
#  'tcp.srcport': '49212',
#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '64240',
#  'tcp.window_size_scalefactor': '-2',
#  'tcp.window_size_value': '64240'}
# --- HTTP LAYER ---
# --- SSL LAYER ---
# {'ssl.handshake.challenge': 'Challenge',
#  'ssl.handshake.challenge_length': '16',
#  'ssl.handshake.cipher_spec_len': '45',
#  'ssl.handshake.cipherspec': '47',
#  'ssl.handshake.ciphersuites': 'Cipher Specs (15 specs)',
#  'ssl.handshake.session_id_length': '0',
#  'ssl.handshake.type': '1',
#  'ssl.handshake.version': '0x00000301',
#  'ssl.record': 'SSLv2 Record Layer: Client Hello',
#  'ssl.record.length': '70',
#  'ssl.record.version': '0x00000002'}
# --- TLS LAYER ---
#
#  *** PKT: 2695 ***
# ['ETH', 'IP', 'TCP', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:0c:29:8a:cb:e9',
#  'eth.addr_resolved': '00:0c:29:8a:cb:e9',
#  'eth.dst': '00:0c:29:8a:cb:e9',
#  'eth.dst_resolved': '00:0c:29:8a:cb:e9',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:50:56:f9:05:c4',
#  'eth.src_resolved': '00:50:56:f9:05:c4',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: United States',
#  'ip.addr': '134.170.109.176',
#  'ip.checksum': '0x0000f35d',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '172.16.223.132',
#  'ip.dst_host': '172.16.223.132',
#  'ip.flags': '0x00000000',
#  'ip.flags.df': '0',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.src_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '134.170.109.176',
#  'ip.id': '0x0000c22a',
#  'ip.len': '1408',
#  'ip.proto': '6',
#  'ip.src': '134.170.109.176',
#  'ip.src_host': '134.170.109.176',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '73',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '1368',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '1368',
#  'tcp.checksum': '0x00002dcd',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '49212',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '1368',
#  'tcp.nxtseq': '1369',
#  'tcp.port': '443',
# --- IP LAYER ---
# {'': 'Source GeoIP: United States',
#  'ip.addr': '134.170.109.176',
#  'ip.checksum': '0x0000f823',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '172.16.223.132',
#  'ip.dst_host': '172.16.223.132',
#  'ip.flags': '0x00000000',
#  'ip.flags.df': '0',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.src_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '134.170.109.176',
#  'ip.id': '0x0000c234',
#  'ip.len': '176',
#  'ip.proto': '6',
#  'ip.src': '134.170.109.176',
#  'ip.src_host': '134.170.109.176',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '73',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '136',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '136',
#  'tcp.checksum': '0x0000be2c',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '49212',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '136',
#  'tcp.nxtseq': '5609',
#  'tcp.port': '443',
#  'tcp.segment_data': 'a4:e1:69:7c:32:d0:04:7b:f7:a9:1d:97:3b:d5:59:bf:cb:6f:9d:a4:b6:a5:bb:41:11:ed:c8:91:83:15:55:ae:59:36:b7:9f:6a:f0:b8:38:f9:7c:32:25:95:cc:33:f1:31:e7:df:cb:78:4b:36:1f:f4:55:e0:bd:28:f9:ca:b9:64:99:ce:eb:61:e9:81:72:94:d3:9b:cd:0a:2b:2a:a4:94:83:ae:6a:0c:23:44:0e:35:ad:a1:e9:ec:d8:d7:75:90:8d:e1:d6:b3:c5:50:fc:5d:d5:fb:6f:92:e1:f4:7e:f0:ae:af:f9:39:b3:ce:4b:01:9c:bd:4e:f7:f1:f2:6f:ce:c0:36:d8:0e:00:00:00',
#  'tcp.seq': '5473',
#  'tcp.srcport': '443',
#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '64240',
#  'tcp.window_size_scalefactor': '-2',
#  'tcp.window_size_value': '64240'}
# --- HTTP LAYER ---
# --- SSL LAYER ---
# {'': 'Random',
#  'ber.64bit_uint_as_bytes': '63:16:85:00:00:01:00:00:d1:5a',
#  'ber.bitstring.padding': '4',
2e:6c:69:76:65:66:69:6c:65:73:74:6f:72:65:2e:63:6f:6d:82:13:2a:2e:6c:69:76:65:66:69:6c:65:73:74:6f:72:65:2e:63:6f:6d:82:1b:2a:2e:62:6c:75:73:6f:61:6b:2e:6c:69:76:65:66:69:6c:65:73:74:6f:72:65:2e:63:6f:6d:82:1b:2a:2e:64:6d:31:73:6f:61:6b:2e:6c:69:76:65:66:69:6c:65:73:74:6f:72:65:2e:63:6f:6d:82:10:73:74:6f:72:61:67:65:2e:6c:69:76:65:2e:63:6f:6d:82:17:2a:2e:62:6c:75:2e:6c:69:76:65:66:69:6c:65:73:74:6f:72:65:2e:63:6f:6d:82:17:2a:2e:62:6e:31:2e:6c:69:76:65:66:69:6c:65:73:74:6f:72:65:2e:63:6f:6d:82:19:2a:2e:63:6f:62:61:6c:74:2e:73:74:6f:72:61:67:65:2e:6c:69:76:65:2e:63:6f:6d:82:17:2a:2e:64:6d:31:2e:6c:69:76:65:66:69:6c:65:73:74:6f:72:65:2e:63:6f:6d:82:0f:2a:2e:64:6f:63:73:2e:6c:69:76:65:2e:6e:65:74:82:13:2a:2e:70:6f:6c:69:63:69:65:73:2e:6c:69:76:65:2e:6e:65:74:82:13:2a:2e:73:65:74:74:69:6e:67:73:2e:6c:69:76:65:2e:6e:65:74:82:17:2a:2e:73: ...
#  'ssl.handshake.certificate_length': '2669',
#  'ssl.handshake.certificates': 'Certificates (5511 bytes)',
#  'ssl.handshake.certificates_length': '5511',
#  'ssl.handshake.ciphersuite': '47',
#  'ssl.handshake.comp_method': '0',
#  'ssl.handshake.extension.len': '1',
#  'ssl.handshake.extension.type': '0x0000ff01',
#  'ssl.handshake.extensions_length': '5',
#  'ssl.handshake.extensions_reneg_info_len': '0',
#  'ssl.handshake.length': '77',
#  'ssl.handshake.random': 'b9:ef:37:df:39:fe:b1:b9:a7:34:98:de:fd:6e:7a:dd:19:ba:ee:51:67:21:27:b7:f0:07:81:fe',
#  'ssl.handshake.random_time': 'Apr 29, 2014 02:44:40.000000000 UTC',
#  'ssl.handshake.session_id': 'ce:4a:00:00:0c:b3:31:f4:08:c6:0f:74:8b:10:e0:c1:2c:0d:60:06:59:c4:3b:fc:94:67:79:6c:e6:f5:3d:11',
#  'ssl.handshake.session_id_length': '32',
#  'ssl.handshake.type': '2',
#  'ssl.handshake.version': '0x00000301',
#  'ssl.record': 'TLSv1 Record Layer: Handshake Protocol: Multiple Handshake '
#                'Messages',
#  'ssl.record.content_type': '22',
#  'ssl.record.length': '5603',
#  'ssl.record.version': '0x00000301',
#  'x509af.Extension_element': 'Extension (id-ms-certificate-template)',
#  'x509af.algorithm.id': '1.2.840.113549.1.1.5',
#  'x509af.algorithmIdentifier_element': 'algorithmIdentifier '
#                                        '(sha1WithRSAEncryption)',
#  'x509af.algorithm_element': 'algorithm (rsaEncryption)',
#  'x509af.critical': '1',
#  'x509af.version': '2',
#  'x509ce.AuthorityKeyIdentifier_element': 'AuthorityKeyIdentifier',
#  'x509ce.BasicConstraintsSyntax_element': 'BasicConstraintsSyntax',
#  'x509ce.CRLDistPointsSyntax': '1',
#  'x509ce.CertificatePoliciesSyntax': '2',
#  'x509ce.CertificateTemplate_element': 'CertificateTemplate',
#  'x509ce.DistributionPoint_element': 'DistributionPoint',
#  'x509ce.GeneralName': '2',
#  'x509ce.GeneralNames': '49',
#  'x509ce.KeyPurposeIDs': '2',
#  'x509ce.KeyPurposeId': '1.3.6.1.5.5.7.3.2',
#  'x509ce.KeyUsage': 'b0',
#  'x509ce.PolicyInformation_element': 'PolicyInformation',
#  'x509ce.PolicyQualifierInfo_element': 'PolicyQualifierInfo',
#  'x509ce.SubjectKeyIdentifier': '75:77:0b:17:79:de:88:a0:fc:d8:d6:af:91:60:30:48:e1:56:f5:89',
#  'x509ce.cA': '1',
#  'x509ce.cRLSign': '0',
#  'x509ce.contentCommitment': '0',
#  'x509ce.dNSName': 'l.live.net',
#  'x509ce.dataEncipherment': '1',
#  'x509ce.decipherOnly': '0',
#  'x509ce.digitalSignature': '1',
#  'x509ce.distributionPoint': '0',
#  'x509ce.encipherOnly': '0',
#  'x509ce.fullName': '3',
#  'x509ce.id': '1.3.6.1.5.5.7.2.1',
#  'x509ce.keyAgreement': '0',
#  'x509ce.keyCertSign': '0',
#  'x509ce.keyEncipherment': '1',
#  'x509ce.keyIdentifier': 'eb:db:11:5e:f8:09:9e:d8:d6:62:9c:fd:62:9d:e3:84:4a:28:e1:27',
#  'x509ce.pathLenConstraint': '0',
#  'x509ce.policyIdentifier': '1.3.6.1.5.5.7.3.2',
#  'x509ce.policyQualifiers': '1',
#  'x509ce.templateID': '1.3.6.1.4.1.311.21.8.7587021.751874.11030412.6202749.3702260.207.945504904.3845423843',
#  'x509ce.templateMajorVersion': '100',
#  'x509ce.templateMinorVersion': '10',
#  'x509ce.uniformResourceIdentifier': 'http://mscrl.microsoft.com/pki/mscorp/crl/MSIT%20Machine%20Auth%20CA%202(1).crl',
#  'x509if.RDNSequence_item': '1',
#  'x509if.RelativeDistinguishedName_item_element': 'RelativeDistinguishedName '
#                                                   'item (dc=com)',
#  'x509if.id': '0.9.2342.19200300.100.1.25',
#  'x509if.rdnSequence': '5',
#  'x509sat.BMPString': 'SubCA',
#  'x509sat.CountryName': 'US',
#  'x509sat.DirectoryString': '1',
#  'x509sat.IA5String': 'com',
#  'x509sat.Integer': '65537',
#  'x509sat.OctetString': '23:b7:d0:ed:68:91:ef:66:9b:e1:05:40:7a:be:67:ca:33:d6:06:bd',
#  'x509sat.printableString': 'MSIT Machine Auth CA 2'}
# --- TLS LAYER ---
#
#  *** PKT: 2702 ***
# ['ETH', 'IP', 'TCP', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:50:56:f9:05:c4',
#  'eth.addr_resolved': '00:50:56:f9:05:c4',
#  'eth.dst': '00:50:56:f9:05:c4',
#  'eth.dst_resolved': '00:50:56:f9:05:c4',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:0c:29:8a:cb:e9',
#  'eth.src_resolved': '00:0c:29:8a:cb:e9',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: Unknown',
#  'ip.addr': '172.16.223.132',
#  'ip.checksum': '0x00000000',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '134.170.109.176',
#  'ip.dst_host': '134.170.109.176',
#  'ip.flags': '0x00000002',
#  'ip.flags.df': '1',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.dst_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '172.16.223.132',
#  'ip.id': '0x00000435',
#  'ip.len': '366',
#  'ip.proto': '6',
#  'ip.src': '172.16.223.132',
#  'ip.src_host': '172.16.223.132',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '5609',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.ack_rtt': '0.000489000',
#  'tcp.analysis.acks_frame': '2701',
#  'tcp.analysis.bytes_in_flight': '326',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '326',
#  'tcp.checksum': '0x00008150',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '443',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '326',
#  'tcp.nxtseq': '399',
#  'tcp.port': '49212',
#  'tcp.seq': '73',
#  'tcp.srcport': '49212',
#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '64104',
#  'tcp.window_size_scalefactor': '-2',
#  'tcp.window_size_value': '64104'}
# --- HTTP LAYER ---
# --- SSL LAYER ---
# {'': 'RSA Encrypted PreMaster Secret',
#  'ssl.change_cipher_spec': 'Change Cipher Spec Message',
#  'ssl.handshake': 'Handshake Protocol: Client Key Exchange',
#  'ssl.handshake.epms': '9d:f4:c3:71:a1:c5:c3:61:23:73:bb:26:d9:bc:2f:93:7e:e1:33:30:c3:db:b9:66:45:61:c2:8e:5d:b7:bf:ea:8b:7e:74:ad:a0:a8:98:00:76:0b:74:24:e9:58:fc:df:fb:5d:4b:ea:33:9f:97:9a:be:1b:82:f2:aa:57:bd:ca:ca:39:b6:f9:aa:05:d6:33:1c:9e:6b:de:ea:1a:71:44:2a:8b:99:26:9a:14:4c:55:2f:5b:a9:e1:3e:06:59:df:61:6b:f7:6c:f2:75:a7:2b:f5:c8:b0:de:4b:89:ac:3f:f2:59:e7:98:2b:dc:53:26:5a:75:a2:15:23:27:54:f4:a5:e4:61:67:fd:31:18:3e:a2:12:d9:eb:c2:f3:ce:bd:03:bf:d6:d6:f5:2b:fa:a5:80:fa:39:aa:4c:77:ec:44:b4:18:06:3d:ac:94:c4:ec:61:58:04:45:2a:1e:e2:93:ad:49:cf:64:32:be:3e:8b:e4:0e:a6:07:b8:a4:a7:60:91:a8:b0:5b:b7:40:c7:d7:fc:aa:11:ab:31:dc:85:fb:f5:a1:23:d6:1f:a9:a1:bd:28:c6:ba:52:d8:1e:1f:ed:9c:c9:d6:3a:3e:55:67:09:c0:b0:a9:2b:1b:8c:de:79:61:93:d2:0c:02:88:78:bf:13:73:f0:d5:52:8d:60:20',
#  'ssl.handshake.epms_len': '256',
#  'ssl.handshake.length': '258',
#  'ssl.handshake.type': '16',
#  'ssl.record': 'TLSv1 Record Layer: Handshake Protocol: Client Key Exchange',
#  'ssl.record.content_type': '22',
#  'ssl.record.length': '262',
#  'ssl.record.version': '0x00000301'}
# --- TLS LAYER ---
#
#  *** PKT: 2704 ***
# ['ETH', 'IP', 'TCP', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:0c:29:8a:cb:e9',
#  'eth.addr_resolved': '00:0c:29:8a:cb:e9',
#  'eth.dst': '00:0c:29:8a:cb:e9',
#  'eth.dst_resolved': '00:0c:29:8a:cb:e9',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:50:56:f9:05:c4',
#  'eth.src_resolved': '00:50:56:f9:05:c4',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: United States',
#  'ip.addr': '134.170.109.176',
#  'ip.checksum': '0x0000f86e',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '172.16.223.132',
#  'ip.dst_host': '172.16.223.132',
#  'ip.flags': '0x00000000',
#  'ip.flags.df': '0',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.src_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '134.170.109.176',
#  'ip.id': '0x0000c236',
#  'ip.len': '99',
#  'ip.proto': '6',
#  'ip.src': '134.170.109.176',
#  'ip.src_host': '134.170.109.176',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '399',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '59',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '59',
#  'tcp.checksum': '0x0000f5b2',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '49212',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '59',
#  'tcp.nxtseq': '5668',
#  'tcp.port': '443',
#  'tcp.seq': '5609',
#  'tcp.srcport': '443',
#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '64240',
#  'tcp.window_size_scalefactor': '-2',
#  'tcp.window_size_value': '64240'}
# --- HTTP LAYER ---
# --- SSL LAYER ---
# {'ssl.change_cipher_spec': 'Change Cipher Spec Message',
#  'ssl.handshake': 'Handshake Protocol: Encrypted Handshake Message',
#  'ssl.record': 'TLSv1 Record Layer: Change Cipher Spec Protocol: Change Cipher '
#                'Spec',
#  'ssl.record.content_type': '20',
#  'ssl.record.length': '1',
#  'ssl.record.version': '0x00000301'}
# --- TLS LAYER ---
#
#  *** PKT: 2705 ***
# ['ETH', 'IP', 'TCP', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:50:56:f9:05:c4',
#  'eth.addr_resolved': '00:50:56:f9:05:c4',
#  'eth.dst': '00:50:56:f9:05:c4',
#  'eth.dst_resolved': '00:50:56:f9:05:c4',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:0c:29:8a:cb:e9',
#  'eth.src_resolved': '00:0c:29:8a:cb:e9',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: Unknown',
#  'ip.addr': '172.16.223.132',
#  'ip.checksum': '0x00000000',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '134.170.109.176',
#  'ip.dst_host': '134.170.109.176',
#  'ip.flags': '0x00000002',
#  'ip.flags.df': '1',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.dst_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '172.16.223.132',
#  'ip.id': '0x00000436',
#  'ip.len': '525',
#  'ip.proto': '6',
#  'ip.src': '172.16.223.132',
#  'ip.src_host': '172.16.223.132',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '5668',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.ack_rtt': '0.009347000',
#  'tcp.analysis.acks_frame': '2704',
#  'tcp.analysis.bytes_in_flight': '485',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '485',
#  'tcp.checksum': '0x000081ef',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '443',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb
# {'eth.addr': '00:0c:29:8a:cb:e9',
#  'eth.addr_resolved': '00:0c:29:8a:cb:e9',
#  'eth.dst': '00:0c:29:8a:cb:e9',
#  'eth.dst_resolved': '00:0c:29:8a:cb:e9',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:50:56:f9:05:c4',
#  'eth.src_resolved': '00:50:56:f9:05:c4',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: United States',
#  'ip.addr': '134.170.109.176',
#  'ip.checksum': '0x0000f343',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '172.16.223.132',
#  'ip.dst_host': '172.16.223.132',
#  'ip.flags': '0x00000000',
#  'ip.flags.df': '0',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.src_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '134.170.109.176',
#  'ip.id': '0x0000c244',
#  'ip.len': '1408',
#  'ip.proto': '6',
#  'ip.src': '134.170.109.176',
#  'ip.src_host': '134.170.109.176',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '884',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '1368',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '1368',
#  'tcp.checksum': '0x00003324',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '49212',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '1368',
#  'tcp.nxtseq': '7036',
#  'tcp.port': '443',
#  'tcp.segment_data': '17:03:01:40:20:53:ae:24:2e:22:c6:bc:16:fa:a5:bf:9e:85:3b:00:86:18:5c:e0:07:f1:43:b8:1d:bd:69:35:65:99:34:5b:9c:d6:16:f9:ea:3a:b2:81:40:88:9e:9c:18:1a:60:ed:1f:29:3a:70:05:7e:de:d6:41:96:fa:34:fa:15:7b:cd:46:bf:db:b1:33:2e:77:41:7f:4d:0b:2e:b3:a5:cf:ee:b0:8b:e6:c1:ae:d8:88:ee:1c:ae:06:4d:8f:c0:24:f7:a6:dd:64:9b:ca:0c:ce:a6:bc:e2:e6:e3:d6:6c:06:ff:14:75:c3:b7:c8:3a:04:60:24:aa:89:51:3c:c6:32:2b:9b:72:5a:b7:41:57:4c:b7:ce:22:83:8a:bd:4a:5b:fa:73:43:78:2

#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '64240',
#  'tcp.window_size_scalefactor': '-2',
#  'tcp.window_size_value': '64240'}
# --- HTTP LAYER ---
# --- SSL LAYER ---
# {'ssl.app_data': 'ec:46:7b:06:36:2d:14:d2:b8:7a:1d:07:d6:51:c4:39:e6:12:bd:fe:04:09:dc:44:ea:f0:ae:00:a9:1c:88:8b',
#  'ssl.record': 'TLSv1 Record Layer: Application Data Protocol: http-over-tls',
#  'ssl.record.content_type': '23',
#  'ssl.record.length': '32',
#  'ssl.record.version': '0x00000301'}
# --- TLS LAYER ---
#
#  *** PKT: 2726 ***
# ['ETH', 'IP', 'TCP', 'DATA', 'SSL', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:0c:29:8a:cb:e9',
#  'eth.addr_resolved': '00:0c:29:8a:cb:e9',
#  'eth.dst': '00:0c:29:8a:cb:e9',
#  'eth.dst_resolved': '00:0c:29:8a:cb:e9',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:50:56:f9:05:c4',
#  'eth.src_resolved': '00:50:56:f9:05:c4',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: United States',
#  'ip.addr': '134.170.109.176',
#  'ip.checksum': '0x0000f337',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '172.16.223.132',
#  'ip.dst_host': '172.16.223.132',
#  'ip.flags': '0x00000000',
#  'ip.flags.df': '0',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.src_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '134.170.109.176',
#  'ip.id': '0x0000c250',
#  'ip.len': '1408',
#  'ip.proto': '6',
#  'ip.src': '134.170.109.176',
#  'ip.src_host': '134.170.109.176',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '884',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '1368',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '1368',
#  'tcp.checksum': '0x000023cb',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '49212',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '1368',
#  'tcp.nxtseq': '23452',
#  'tcp.port': '443',
#  'tcp.segment_data': '31:ce:59:c7:6c:f1:5a:d9:3f:9a:76:57:62:8f:40:c7:65:dd:84:aa:b6:55:11:fa:b8:18:d8:8f:59:fd:53:ad:be:c6:e1:55:67:41:49:14:8a:ee',
#  'tcp.seq': '22084',
#  'tcp.srcport': '443',
#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '
:7b:fa:f9:86:91:27:08:e1:fc:e9:9b:b0:e4:98:77:ba:ee:e0:1f:bc:16:4c:76:0a:94:d3:e2:29:5f:15:f2:7f:3c:fe:5e:4f:8d:da:0d:de:3a:df:0d:42:7b:e9:5d:e6:97:4b:5b:f7:cb:a1:37:9c:8b:6b:82:ef:6b:91:59:f5:3b:e6:ae:c3:ce:9f:94:e0:3b:52:e7:99:9b:16:09:3f:8a:f5:fb:39:0e:ed:fb:bd:35:33:1c:c1:97:a0:37:ad:8c:8d:fd:e1:d9:5b:3b:72:67:41:0e:87:9c:93:23:b8:8a:90:aa:71:81:48:16:03:9e:a2:c9:2c:a1:73:c3:51:fb:2b:9d:ee:24:40:98:b2:62:5b:45:fa:1d:55:5a:35:a2:3e:3a:04:1e:d0:71:3f:d4:03:0b:d9:1b:4d:cc:7a:1f:93:0b:2c:3a:78:2a:14:76:5f:ee:11:91:a6:49:e7:82:a1:48:36:52:77:46:0c:84:bc:cb:48:8f:28:b3:c6:97:cd:96:21:e1:8b:13:14:80:b0:32:e ...
#  'ssl.record': 'TLSv1 Record Layer: Application Data Protocol: http-over-tls',
#  'ssl.record.content_type': '23',
#  'ssl.record.length': '16416',
#  'ssl.record.version': '0x00000301'}
# --- TLS LAYER ---
#
#  *** PKT: 2744 ***
# ['ETH', 'IP', 'TCP', 'DATA', 'SSL', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:0c:29:8a:cb:e9',
#  'eth.addr_resolved': '00:0c:29:8a:cb:e9',
#  'eth.dst': '00:0c:29:8a:cb:e9',
#  'eth.dst_resolved': '00:0c:29:8a:cb:e9',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:50:56:f9:05:c4',
#  'eth.src_resolved': '00:50:56:f9:05:c4',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: United States',
#  'ip.addr': '134.170.109.176',
#  'ip.checksum': '0x0000f329',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '172.16.223.132',
#  'ip.dst_host': '172.16.223.132',
#  'ip.flags': '0x00000000',
#  'ip.flags.df': '0',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.src_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '134.170.109.176',
#  'ip.id': '0x0000c25e',
#  'ip.len': '1408',
#  'ip.proto': '6',
#  'ip.src': '134.170.109.176',
#  'ip.src_host': '134.170.109.176',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '884',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '2736',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '1368',
#  'tcp.checksum': '0x00003e67',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '49212',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '1368',
#  'tcp.nxtseq': '39868',
#  'tcp.port': '443',
#  'tcp.segment_data': '86:89:af:2a:3e:d1:5c:04:f7:3a:53:c5:ad:2d:04:69:bf:4a:74:57:f3:95:c7:80:8e:a9:62:d3:48:e1:b9:c3:aa:2f:ad:fe:ef:fe:eb:5b:e1:a5:07:4d:ab:db:c8:69:c8:45:10:88:89:96:ba:7f:84:a1:49:bf:0f:30:95:b3:36:40:96:ea:8c:74:68:d3:25:22:61:09:dc:79:a1:7f:0b:52:55:8e',
#  'tcp.seq': '38500',
#  'tcp.srcport': '443',
#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '64240',
#  'tcp.window_size_scalefactor': '-2',
#  'tcp.window_size_value': '64240'}
# --- HTTP LAYER ---
# --- SSL LAYER ---
# ...
#  'tcp.seq': '153025',
#  'tcp.srcport': '443',
#  'tcp.stream': '15',
#  'tcp.urgent_pointer': '0',
#  'tcp.window_size': '64240',
#  'tcp.window_size_scalefactor': '-2',
#  'tcp.window_size_value': '64240'}
# --- HTTP LAYER ---
# --- SSL LAYER ---
# {'ssl.app_data': 'f0:8d:71:8c:2b:9a:40:ed:42:d9:2c:bf:73:9a:00:07:3e:17:3f:dd:72:88:c7:5d:08:a5:e9:88:36:39:83:b0:42:63:ee:81:28:e0:b2:5b:ff:4e:89:f1:4b:0b:0e:87:a3:fe:77:14:a3:81:ef:4b:78:d8:cd:54:92:40:75:75:df:d3:e2:18:29:bc:a5:e7:87:87:d8:c7:0f:36:2a:64:71:13:c7:4b:94:5d:00:1f:fd:09:95:5c:f1:e1:54:a4:36:f7:fd:9e:82:35:c5:0e:fe:4f:92:78:9f:d6:ef:17:f8:b5:d4:1e:e8:c7:0a:d9:da:8a:5f:d9:2f:b5:df:4c:9d:5a:cf:db:06:ce:b9:85:18:22:57:5f:63:d2:fd:6c:1c:06:59:3e:91:f5:c7:37:5f:30:9b:8a:1a:a2:02:c4:c7:99:88:88:b8:bb:8c:be:62:db:4f:16:52:a1:d9:59:6e:ce:75:75:5f:7f:47:16:01:e6:cf:06:fa:85:c8:ea:f0:57:99:46:29:38:a2:99:fb:20:01:57:d6:13:6e:9e:a3:72:1d:58:f2:bf:f8:3e:d2:31:e7:1a:e6:20:0e:99:69:9c:6e:f3:63:71:f5:9d:32:f7:5d:ed:ec:46:3b:84:f2:d3:c4:cf:a2:f8:9b:9d:ca:77:11:26:e3:aa:36:28:0a:bd:71:7f:f2:e4:e6:95:a9:b5:45:5c:d7:dc:d5:6e:58:eb:2e:7e:92:9d:3f:96:1f:b7:0f:b7:c7:f3:a1:95:39:28:eb:0f:46:ce:60:7a:76:40:92:c8:1b:84:f5:43:c1:99:21:78:d6:a0:42:a8:f2:85:92:fe:a0:75:c2:a2:6f:ea:cb:82:4e:44:90:e0:b0:9c:bd:46:49:be:bc:7c:7b:68:36:56:84:a5:f6:f5:f2:
:f4:08:9f:31:c0:5f:dd:af:75:47:b0:0a:55:6e:2e:0a:02:0b:35:74:e1:d5:5b:cd:e7:06:fd:5c:95:ec:87:a2:90:fa:37:db:bf:ce:6f:2b:85:29:e3:96:6e:df:8a:da:cf:54:58:af:00:2d:ce:50:79:1e:81:df:c9:f5:8f:84:03:b5:07:12:86:ef:7c:16:b5:89:3a:34:9a:f5:88:b9:73:6c:7a:af:9c:a8:35:bd:f8:e0:2e:6d:bc:4d:8d:c2:62:da:cb:65:28:26:c8:b7:a1:07:e9:10:69:fb:81:bc:1e:59:b3:40:8b:e7:8e:0a:71:47:52:3f:a5:96:73:60:1e:ce:19:a2:89:29:2e:2d:31:3d:4c:28:bb:35:fb:bb:5a:56:3d:9d:a5:74:87:98:58:c0:86:95:bf:e1:b5:d0:1a:ab:b0:93:03:70:ee:e1:d0:8b:c4:a9:7f:87:b8:d7:ef:16:6a:d2:2e:1a:ea:56:1b:68:f8:98:11:8b:dc:fb:ac:29:89:b5:a2:d0:1c:bd:b9:db:eb:bf:99:2b:4a:4c:e8:3d:5a:39:6f:79:0a:07:af:f0:08:c5:a8:cf:7d:0e:62:1c:23:dc:f7:00:1d:83:e7:d9:19:43:76:14:64:86:ff:a6:dc:79:52:c6:cf:84:28:d8:9f:d5:fa:99:22:62:32:c5:cf:e2:6c:e7:9c:d3:75:32:8a:a2:6a:36:b7:3c:12:20:b4:cf:f0:2f:c2:df:c9:25:1f:a3:82:52:8b:f3:9f:b3:65:37:29:04:56:59:0b:d3:a1:38:fa:37:66:a1:a7:ca:19:dc:ff:26:61:ed:eb:43:c6:18:c3:cd:f6:49:14:3b:b2:6e:6a:95:12:e4:80:f3:41:61:d8:9c:51:e8:8d:eb:2c:b2:56:57:a7:a1:8d:65:94:d6:c9:c7:ca:0c:65:34:1d:b1:28:37:98:92:cf:8d:1b:0c:41:5c:7d:c7:7e:c0:e1:df:a9:5d:57:98:bc:0c:6b:a9:3e:76:f3:56:2b:59:35:80:d4:61:1d:4 ...
#  'ssl.record': 'TLSv1 Record Layer: Application Data Protocol: http-over-tls',
#  'ssl.record.content_type': '23',
#  'ssl.record.length': '16416',
#  'ssl.record.version': '0x00000301'}
# --- TLS LAYER ---
#
#  *** PKT: 2866 ***
# ['ETH', 'IP', 'TCP', 'DATA', 'SSL']
# --- ETH LAYER ---
# {'eth.addr': '00:0c:29:8a:cb:e9',
#  'eth.addr_resolved': '00:0c:29:8a:cb:e9',
#  'eth.dst': '00:0c:29:8a:cb:e9',
#  'eth.dst_resolved': '00:0c:29:8a:cb:e9',
#  'eth.ig': '0',
#  'eth.lg': '0',
#  'eth.src': '00:50:56:f9:05:c4',
#  'eth.src_resolved': '00:50:56:f9:05:c4',
#  'eth.type': '0x00000800'}
# --- IP LAYER ---
# {'': 'Source GeoIP: United States',
#  'ip.addr': '134.170.109.176',
#  'ip.checksum': '0x0000f712',
#  'ip.checksum.status': '2',
#  'ip.dsfield': '0x00000000',
#  'ip.dsfield.dscp': '0',
#  'ip.dsfield.ecn': '0',
#  'ip.dst': '172.16.223.132',
#  'ip.dst_host': '172.16.223.132',
#  'ip.flags': '0x00000000',
#  'ip.flags.df': '0',
#  'ip.flags.mf': '0',
#  'ip.flags.rb': '0',
#  'ip.frag_offset': '0',
#  'ip.geoip.country': 'United States',
#  'ip.geoip.src_country': 'United States',
#  'ip.hdr_len': '20',
#  'ip.host': '134.170.109.176',
#  'ip.id': '0x0000c2c9',
#  'ip.len': '300',
#  'ip.proto': '6',
#  'ip.src': '134.170.109.176',
#  'ip.src_host': '134.170.109.176',
#  'ip.ttl': '128',
#  'ip.version': '4'}
# --- UDP LAYER ---
# --- DNS LAYER ---
# --- TCP LAYER ---
# {'tcp.ack': '884',
#  'tcp.analysis': 'SEQ/ACK analysis',
#  'tcp.analysis.bytes_in_flight': '7560',
#  'tcp.analysis.initial_rtt': '0.034256000',
#  'tcp.analysis.push_bytes_sent': '7560',
#  'tcp.checksum': '0x0000fa2f',
#  'tcp.checksum.status': '2',
#  'tcp.dstport': '49212',
#  'tcp.flags': '0x00000018',
#  'tcp.flags.ack': '1',
#  'tcp.flags.cwr': '0',
#  'tcp.flags.ecn': '0',
#  'tcp.flags.fin': '0',
#  'tcp.flags.ns': '0',
#  'tcp.flags.push': '1',
#  'tcp.flags.res': '0',
#  'tcp.flags.reset': '0',
#  'tcp.flags.str': '\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7AP\\xc2\\xb7\\xc2\\xb7\\xc2\\xb7',
#  'tcp.flags.syn': '0',
#  'tcp.flags.urg': '0',
#  'tcp.hdr_len': '20',
#  'tcp.len': '260',
#  'tcp.nxtseq': '169896',
#  'tcp.port': '443',
#  'tcp.segment_data': 'ff:36:09:14:5c:59:89:04:6d:79:98:6e:c6:f9:cd:a3:a4:8f:bb:5d:f0:8f:b9:a4:c1:f8:01:54:a1:61:e3:44:f7:ce:3d:03:18:e2:66:a1:17:e7:38:dc:ad:81:94:08:07:01:c4:4d:6c:37:32:20:9b:1e:75:40:de:ff:3f:2d:02:1c:5f:28:05:a8:0c:a1:f2:cb:38:45:b9:c1:e6:a3:8d:4f:bd:0f:4b:11:fc:c0:04:57:5e:98:79:d0:3b:79:bb:d6:0f:53:ee:48:db:11:21:d5:d1:44:9f:e4:db:64:2a:c9:73:5c:54:6f:10:d4:04:51:13:50:d4:36:5b:47:96:3d:d7:85:12:b9:4d:aa:14:03:ce:1c:80:40:ff:9c:f3:98:0c:3b:e7:8a:f7:47:48:f6:16:f8:b2:08:a8:72:79:da:b6:b0:97:9f:78:1f:32:92:49:30:06:f7:cb:e4:2c:48:58:b5:5d:6d:1f:01:60:fe:97:80:d2:35:89:64:3b:09:2e:d4:4d:0f:5c:e2:1e:04:a5:44:86:23:19:17:cc:c5:96:82:db:d4:a3:08:e5:3a:05:38:9a:c7:d0:9d:cb:c1:e1:47:e8:5b:52:71:f2:fb:0a:4f:93:b3:fe:45:2c:f8:bf:20:e0:61:4c:64:98:28:d3:44:40:fc:fe:bf:a4:38:ad:78',
#  'tcp.seq': '169636',
#  'tcp.srcport': '443',
a:c8:2e:b5:1a:e5:ff:b8:c6:85:cb:00:18:e2:45:4d:d9:68:f5:43:aa:b1:5c:9d:dc:7d:b0:10:34:7f:7b:5b:48:3e:ea:a2:15:a9:f3:7f:f8:22:c7:24:d5:16:3f:9e:c0:c7:60:69:ed:f2:f6:02:9b:7b:f6:40:48:29:c1:85:86:3c:ec:da:96:32:94:07:04:34:bb:8b:bc:da:a4:49:67:95:ca:d5:26:53:f8:54:8d:1f:bb:4d:01:79:7e:a3:0f:54:b2:f4:5c:1a:75:fb:47:d5:44:9f:8f:9b:60:e5:1a:97:3e:0f:7c:01:fe:95:92:6c:e3:92:41:ad:b7:bc:9c:b2:e9:6e:92:23:40:3d:60:74:0b:11:ba:26:44:3a:76:95:3e:ad:54:af:97:e5:fc:5a:13:b7:65:4a:63:7c:e7:d7:6e:d6:52:9b:08:2f:8a:0c:ed:72:81:11:ec:e7:f8:a6:8f:3b:af:42:80:7a:36:35:a3:58:4c:c7:d3:f ...
#  'ssl.record': 'TLSv1 Record Layer: Application Data Protocol: http-over-tls',
#  'ssl.record.content_type': '23',
#  'ssl.record.length': '16064',
#  'ssl.record.version': '0x00000301'}
# --- TLS LAYER ---
# Layers
# ['UDP', 'TCP', 'DNS', 'MEDIA', 'IMAGE', 'DATA', 'SSL', 'IP', 'ETH', 'HTTP', 'PNG']
#
# Failed PCAPS
# []
# ETH Set
# ['eth.dst_resolved', 'eth.src', 'eth.dst', 'eth.addr_resolved', 'eth.ig', 'eth.src_resolved', 'eth.addr', 'eth.type', 'eth.lg']
# IP Set
# ['', 'ip.flags.df', 'ip.version', 'ip.id', 'ip.checksum.status', 'ip.geoip.country', 'ip.host', 'ip.proto', 'ip.dst_host', 'ip.geoip.dst_country', 'ip.flags.mf', 'ip.geoip.src_country', 'ip.frag_offset', 'ip.len', 'ip.hdr_len', 'ip.dst', 'ip.dsfield.ecn', 'ip.src_host', 'ip.checksum', 'ip.src', 'ip.ttl', 'ip.flags', 'ip.dsfield', 'ip.flags.rb', 'ip.addr', 'ip.dsfield.dscp']
# UDP Set
# []
# DNS Set
# []
# TCP Set
# ['tcp.flags.fin', 'tcp.flags.syn', 'tcp.stream', 'tcp.flags.urg', 'tcp.urgent_pointer', 'tcp.checksum', 'tcp.window_size_value', 'tcp.port', 'tcp.checksum.status', 'tcp.segment_data', 'tcp.flags.res', 'tcp.hdr_len', 'tcp.len', 'tcp.analysis.ack_rtt', 'tcp.flags.ns', 'tcp.flags.ack', 'tcp.window_size_scalefactor', 'tcp.srcport', 'tcp.ack', 'tcp.nxtseq', 'tcp.analysis.acks_frame', 'tcp.analysis.bytes_in_flight', 'tcp.flags.cwr', 'tcp.flags', 'tcp.window_size', 'tcp.analysis', 'tcp.dstport', 'tcp.seq', 'tcp.flags.reset', 'tcp.analysis.push_bytes_sent', 'tcp.flags.ecn', 'tcp.flags.str', 'tcp.analysis.initial_rtt', 'tcp.flags.push']
# HTTP Set
# []
# SSL Set
# ['', 'ssl.handshake.challenge', 'x509ce.id', 'x509ce.templateMajorVersion', 'x509ce.pathLenConstraint', 'x509af.Extension_element', 'x509ce.keyCertSign', 'x509af.algorithm.id', 'x509ce.distributionPoint', 'x509ce.templateID', 'ber.bitstring.padding', 'ssl.handshake.extension.len', 'x509ce.keyIdentifier', 'x509sat.OctetString', 'x509ce.KeyPurposeIDs', 'ssl.handshake.length', 'ssl.record.length', 'ssl.handshake.type', 'x509if.RDNSequence_item', 'ssl.handshake.session_id_length', 'x509ce.GeneralNames', 'x509ce.PolicyInformation_element', 'x509af.utcTime', 'ssl.handshake.cipherspec', 'x509ce.policyQualifiers', 'ssl.handshake.extension.type', 'x509if.rdnSequence', 'x509if.id', 'x509af.subject', 'x509ce.dataEncipherment', 'x509ce.contentCommitment', 'ssl.app_data', 'ssl.handshake.ciphersuite', 'x509af.extension.id', 'ssl.handshake.certificates', 'x509ce.decipherOnly', 'x509ce.KeyUsage', 'x509ce.CertificatePoliciesSyntax', 'x509ce.PolicyQualifierInfo_element', 'pkix1implicit.AuthorityInfoAccessSyntax', 'ssl.handshake.epms_len', 'x509sat.printableString', 'x509af.critical', 'x509if.RelativeDistinguishedName_item_element', 'ssl.handshake.certificate_length', 'ssl.handshake.certificates_length', 'x509af.subjectPublicKey', 'x509ce.templateMinorVersion', 'x509sat.BMPString', 'x509af.signature_element', 'ssl.handshake', 'x509af.version', 'ssl.change_cipher_spec', 'x509ce.policyIdentifier', 'x509af.notAfter', 'x509ce.encipherOnly', 'x509ce.cRLSign', 'x509ce.BasicConstraintsSyntax_element', 'ssl.handshake.certificate', 'pkcs1.publicExponent', 'x509af.algorithmIdentifier_element', 'x509ce.dNSName', 'pkix1implicit.AccessDescription_element', 'ssl.handshake.ciphersuites', 'ssl.record.version', 'x509ce.keyAgreement', 'ssl.handshake.random', 'x509af.encrypted', 'x509ce.fullName', 'x509ce.KeyPurposeId', 'ssl.record', 'ssl.handshake.epms', 'pkix1implicit.accessLocation', 'x509ce.digitalSignature', 'pkix1explicit.DirectoryString', 'x509ce.cA', 'ssl.handshake.version', 'x509af.serialNumber', 'ssl.handshake.extensions_reneg_info_len', 'x509ce.keyEncipherment', 'x509ce.CRLDistPointsSyntax', 'x509af.validity_element', 'ber.64bit_uint_as_bytes', 'x509ce.SubjectKeyIdentifier', 'x509af.notBefore', 'x509sat.CountryName', 'x509sat.DirectoryString', 'ssl.handshake.random_time', 'x509af.signedCertificate_element', 'ssl.handshake.comp_method', 'x509ce.GeneralName', 'ssl.record.content_type', 'ssl.handshake.session_id', 'x509af.extensions', 'x509ce.DistributionPoint_element', 'x509af.algorithm_element', 'pkcs1.modulus', 'x509ce.CertificateTemplate_element', 'x509sat.IA5String', 'x509ce.AuthorityKeyIdentifier_element', 'ssl.handshake.challenge_length', 'x509af.subjectPublicKeyInfo_element', 'ssl.handshake.cipher_spec_len', 'x509sat.Integer', 'x509af.issuer', 'pkix1implicit.accessMethod', 'ssl.handshake.extensions_length', 'x509af.rdnSequence', 'x509ce.uniformResourceIdentifier']
# TLS Set
# []
